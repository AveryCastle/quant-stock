# %%
import pandas as pd

# %%
url_tmpl = 'http://companyinfo.stock.naver.com/v1/company/ajax/cF1001.aspx?cmp_cd=%s&fin_typ=%s&freq_typ=%s'
url = url_tmpl % ('005930', '4', 'Y') # 삼성전자, 4(IFRS 연결), Y:년 단위

dfs = pd.read_html(url, encoding='utf8')
# dfs
df = dfs[0]
# print(df)
df = df.set_index('주요재무정보')
df.head(10) # 10개 항목만 표시(실제 32개 항목)
# Out:
#                                                                                                          연간  \
#               \n\t\t\t\t\t\t\t\t\t2013/12\n\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t(IFRS연결)\n\t\t\t\t\t\t\t\t
# 주요재무정보
# (매출액,)                                                 2011036.0
# (영업이익,)                                                 290493.0
# (영업이익(발표기준),)                                           290493.0
# (세전계속사업이익,)                                             299150.0
# (당기순이익,)                                                238453.0
# (당기순이익(지배),)                                            231854.0
# (당기순이익(비지배),)                                             6599.0
# (자산총계,)                                                1810716.0
# (부채총계,)                                                 595914.0
# (자본총계,)                                                1214802.0
#
#                                                                                          Unnamed: 2_level_0  \
#               \n\t\t\t\t\t\t\t\t\t2014/12\n\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t(IFRS연결)\n\t\t\t\t\t\t\t\t
# 주요재무정보
# (매출액,)                                                 2286927.0
# (영업이익,)                                                 367850.0
# (영업이익(발표기준),)                                           367850.0
# (세전계속사업이익,)                                             383643.0
# (당기순이익,)                                                304748.0
# (당기순이익(지배),)                                            298212.0
# (당기순이익(비지배),)                                             6535.0
# (자산총계,)                                                2140750.0
# (부채총계,)                                                 640590.0
# (자본총계,)                                                1500160.0
#
#                                                                                          Unnamed: 3_level_0  \
#               \n\t\t\t\t\t\t\t\t\t2015/12\n\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t(IFRS연결)\n\t\t\t\t\t\t\t\t
# 주요재무정보
# (매출액,)                                                 2062060.0
# (영업이익,)                                                 250251.0
# (영업이익(발표기준),)                                           250251.0
# (세전계속사업이익,)                                             278750.0
# (당기순이익,)                                                233944.0
# (당기순이익(지배),)                                            230825.0
# (당기순이익(비지배),)                                             3119.0
# (자산총계,)                                                2304230.0
# (부채총계,)                                                 623348.0
# (자본총계,)                                                1680882.0
#
#                                                                                          Unnamed: 4_level_0  \
#               \n\t\t\t\t\t\t\t\t\t2016/12\n\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t(IFRS연결)\n\t\t\t\t\t\t\t\t
# 주요재무정보
# (매출액,)                                                 2006535.0
# (영업이익,)                                                 264134.0
# (영업이익(발표기준),)                                           264134.0
# (세전계속사업이익,)                                             259610.0
# (당기순이익,)                                                190601.0
# (당기순이익(지배),)                                            186946.0
# (당기순이익(비지배),)                                             3655.0
# (자산총계,)                                                2421795.0
# (부채총계,)                                                 631197.0
# (자본총계,)                                                1790598.0
#
#                                                                                             Unnamed: 5_level_0  \
#               \n\t\t\t\t\t\t\t\t\t2017/12(E)\n\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t(IFRS연결)\n\t\t\t\t\t\t\t\t
# 주요재무정보
# (매출액,)                                                 2018667.0
# (영업이익,)                                                 292407.0
# (영업이익(발표기준),)                                           292407.0
# (세전계속사업이익,)                                             307137.0
# (당기순이익,)                                                227261.0
# (당기순이익(지배),)                                            224157.0
# (당기순이익(비지배),)                                             3104.0
# (자산총계,)                                                2621743.0
# (부채총계,)                                                 692113.0
# (자본총계,)                                                1929630.0
#
#                                                                                             Unnamed: 6_level_0  \
#               \n\t\t\t\t\t\t\t\t\t2018/12(E)\n\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t(IFRS연결)\n\t\t\t\t\t\t\t\t
# 주요재무정보
# (매출액,)                                                 2404376.0
# (영업이익,)                                                 543946.0
# (영업이익(발표기준),)                                                NaN
# (세전계속사업이익,)                                             556823.0
# (당기순이익,)                                                420223.0
# (당기순이익(지배),)                                            412331.0
# (당기순이익(비지배),)                                                NaN
# (자산총계,)                                                3027703.0
# (부채총계,)                                                 792611.0
# (자본총계,)                                                2233953.0
#
#                                                                                             Unnamed: 7_level_0  \
#               \n\t\t\t\t\t\t\t\t\t2019/12(E)\n\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t(IFRS연결)\n\t\t\t\t\t\t\t\t
# 주요재무정보
# (매출액,)                                                 2605815.0
# (영업이익,)                                                 627201.0
# (영업이익(발표기준),)                                                NaN
# (세전계속사업이익,)                                             647864.0
# (당기순이익,)                                                483281.0
# (당기순이익(지배),)                                            474951.0
# (당기순이익(비지배),)                                                NaN
# (자산총계,)                                                3462906.0
# (부채총계,)                                                 830378.0
# (자본총계,)                                                2631257.0
#
#               Unnamed: 8_level_0
#               Unnamed: 8_level_1
# 주요재무정보
# (매출액,)                 2698530.0
# (영업이익,)                 628795.0
# (영업이익(발표기준),)                NaN
# (세전계속사업이익,)             653630.0
# (당기순이익,)                487383.0
# (당기순이익(지배),)            478981.0
# (당기순이익(비지배),)                NaN
# (자산총계,)                3870008.0
# (부채총계,)                 860671.0
# (자본총계,)                3006898.0

# %% [markdown]
# # 컬럼 변환

# %%
# 리스트로 전환
cols = []

for year in range(2012, 2020):
    cols.append(str(year) + '/12')
    
cols
# Out:
# ['2012/12',
#  '2013/12',
#  '2014/12',
#  '2015/12',
#  '2016/12',
#  '2017/12',
#  '2018/12',
#  '2019/12']

# %%
df.columns = cols
df.head()
# Out:
#                  2012/12    2013/12    2014/12    2015/12    2016/12  \
# 주요재무정보
# (매출액,)         2011036.0  2286927.0  2062060.0  2006535.0  2018667.0
# (영업이익,)         290493.0   367850.0   250251.0   264134.0   292407.0
# (영업이익(발표기준),)   290493.0   367850.0   250251.0   264134.0   292407.0
# (세전계속사업이익,)     299150.0   383643.0   278750.0   259610.0   307137.0
# (당기순이익,)        238453.0   304748.0   233944.0   190601.0   227261.0
#
#                  2017/12    2018/12    2019/12
# 주요재무정보
# (매출액,)         2404376.0  2605815.0  2698530.0
# (영업이익,)         543946.0   627201.0   628795.0
# (영업이익(발표기준),)        NaN        NaN        NaN
# (세전계속사업이익,)     556823.0   647864.0   653630.0
# (당기순이익,)        420223.0   483281.0   487383.0

# %% [markdown]
# # Index  변환

# %%
indexes = []

for i in range(0, df.index.size):
    indexes.append(df.index[i][0])
    
indexes
# Out:
# ['매출액',
#  '영업이익',
#  '영업이익(발표기준)',
#  '세전계속사업이익',
#  '당기순이익',
#  '당기순이익(지배)',
#  '당기순이익(비지배)',
#  '자산총계',
#  '부채총계',
#  '자본총계',
#  '자본총계(지배)',
#  '자본총계(비지배)',
#  '자본금',
#  '영업활동현금흐름',
#  '투자활동현금흐름',
#  '재무활동현금흐름',
#  'CAPEX',
#  'FCF',
#  '이자발생부채',
#  '영업이익률',
#  '순이익률',
#  'ROE(%)',
#  'ROA(%)',
#  '부채비율',
#  '자본유보율',
#  'EPS(원)',
#  'PER(배)',
#  'BPS(원)',
#  'PBR(배)',
#  '현금DPS(원)',
#  '현금배당수익률',
#  '현금배당성향(%)',
#  '발행주식수(보통주)']

# %%
df.head(5)
# Out:
#                  2012/12    2013/12    2014/12    2015/12    2016/12  \
# 주요재무정보
# (매출액,)         2011036.0  2286927.0  2062060.0  2006535.0  2018667.0
# (영업이익,)         290493.0   367850.0   250251.0   264134.0   292407.0
# (영업이익(발표기준),)   290493.0   367850.0   250251.0   264134.0   292407.0
# (세전계속사업이익,)     299150.0   383643.0   278750.0   259610.0   307137.0
# (당기순이익,)        238453.0   304748.0   233944.0   190601.0   227261.0
#
#                  2017/12    2018/12    2019/12
# 주요재무정보
# (매출액,)         2404376.0  2605815.0  2698530.0
# (영업이익,)         543946.0   627201.0   628795.0
# (영업이익(발표기준),)        NaN        NaN        NaN
# (세전계속사업이익,)     556823.0   647864.0   653630.0
# (당기순이익,)        420223.0   483281.0   487383.0

# %%
# new_indexes = {v: k for v, k in enumerate(indexes)}

new_index_dict = dict(zip(df.index, indexes))
print(new_index_dict)

df.rename(new_index_dict, axis='index', inplace=True)
df.head(5)
# Out:
# {('매출액',): '매출액', ('영업이익',): '영업이익', ('영업이익(발표기준)',): '영업이익(발표기준)', ('세전계속사업이익',): '세전계속사업이익', ('당기순이익',): '당기순이익', ('당기순이익(지배)',): '당기순이익(지배)', ('당기순이익(비지배)',): '당기순이익(비지배)', ('자산총계',): '자산총계', ('부채총계',): '부채총계', ('자본총계',): '자본총계', ('자본총계(지배)',): '자본총계(지배)', ('자본총계(비지배)',): '자본총계(비지배)', ('자본금',): '자본금', ('영업활동현금흐름',): '영업활동현금흐름', ('투자활동현금흐름',): '투자활동현금흐름', ('재무활동현금흐름',): '재무활동현금흐름', ('CAPEX',): 'CAPEX', ('FCF',): 'FCF', ('이자발생부채',): '이자발생부채', ('영업이익률',): '영업이익률', ('순이익률',): '순이익률', ('ROE(%)',): 'ROE(%)', ('ROA(%)',): 'ROA(%)', ('부채비율',): '부채비율', ('자본유보율',): '자본유보율', ('EPS(원)',): 'EPS(원)', ('PER(배)',): 'PER(배)', ('BPS(원)',): 'BPS(원)', ('PBR(배)',): 'PBR(배)', ('현금DPS(원)',): '현금DPS(원)', ('현금배당수익률',): '현금배당수익률', ('현금배당성향(%)',): '현금배당성향(%)', ('발행주식수(보통주)',): '발행주식수(보통주)'}
#               2012/12    2013/12    2014/12    2015/12    2016/12    2017/12  \
# 주요재무정보
# 매출액         2011036.0  2286927.0  2062060.0  2006535.0  2018667.0  2404376.0
# 영업이익         290493.0   367850.0   250251.0   264134.0   292407.0   543946.0
# 영업이익(발표기준)   290493.0   367850.0   250251.0   264134.0   292407.0        NaN
# 세전계속사업이익     299150.0   383643.0   278750.0   259610.0   307137.0   556823.0
# 당기순이익        238453.0   304748.0   233944.0   190601.0   227261.0   420223.0
#
#               2018/12    2019/12
# 주요재무정보
# 매출액         2605815.0  2698530.0
# 영업이익         627201.0   628795.0
# 영업이익(발표기준)        NaN        NaN
# 세전계속사업이익     647864.0   653630.0
# 당기순이익        483281.0   487383.0

# %% [markdown]
# # NaN을 0.0 숫자로 바꾸기

# %%
df.fillna(0, inplace=True)
df.head()
# Out:
#               2012/12    2013/12    2014/12    2015/12    2016/12    2017/12  \
# 주요재무정보
# 매출액         2011036.0  2286927.0  2062060.0  2006535.0  2018667.0  2404376.0
# 영업이익         290493.0   367850.0   250251.0   264134.0   292407.0   543946.0
# 영업이익(발표기준)   290493.0   367850.0   250251.0   264134.0   292407.0        0.0
# 세전계속사업이익     299150.0   383643.0   278750.0   259610.0   307137.0   556823.0
# 당기순이익        238453.0   304748.0   233944.0   190601.0   227261.0   420223.0
#
#               2018/12    2019/12
# 주요재무정보
# 매출액         2605815.0  2698530.0
# 영업이익         627201.0   628795.0
# 영업이익(발표기준)        0.0        0.0
# 세전계속사업이익     647864.0   653630.0
# 당기순이익        483281.0   487383.0

# %% [markdown]
# # column & row change

# %%
dft = df.T

# 첫번째 컬럼 이름을 data로 변경
dft.rename(columns={'주요재무정보':'date'}, inplace=True)

# 인덱스를 날짜형식(datetime)으로 변환
dft.index = pd.to_datetime(dft.index)

dft[['매출액', '당기순이익', '부채총계', 'PER(배)' , 'PBR(배)', '현금배당수익률']]
# Out:
# 주요재무정보            매출액     당기순이익      부채총계  PER(배)  PBR(배)  현금배당수익률
# 2012-12-01  2011036.0  238453.0  595914.0   11.17    1.96     0.53
# 2013-12-01  2286927.0  304748.0  640590.0    7.83    1.43     1.04
# 2014-12-01  2062060.0  233944.0  623348.0    9.78    1.23     1.51
# 2015-12-01  2006535.0  190601.0  631197.0   11.47    1.06     1.67
# 2016-12-01  2018667.0  227261.0  692113.0   13.18    1.35     1.58
# 2017-12-01  2404376.0  420223.0  792611.0    9.64    1.64     1.33
# 2018-12-01  2605815.0  483281.0  830378.0    7.56    1.30     2.85
# 2019-12-01  2698530.0  487383.0  860671.0    7.49    1.14     2.93
